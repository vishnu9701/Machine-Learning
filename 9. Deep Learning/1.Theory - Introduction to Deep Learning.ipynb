# %% [markdown]
# ## Deep Learning
#  Deep Learning (DL) is a subset of Machine Learning (ML) that allows us to train a model using a set of inputs and then predict output based.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Introduction to Neural Network

# %% [markdown]
# **a) Input Layer**
# It receives input and passes it to hidden layers.
#
# **b) Hidden Layers**
# There can be 1 or more hidden layers in Deep Neural Network (DNN). “Deep” in DL refers to having more than 1 layer. All computations are done by hidden layers.
#
# c) Output Layer
# This layer receives input from the last hidden layer and gives the output.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Working of Artificial Neural Networks
#  perceptron can be defined as a neural network with a single layer that classifies the linear data. It further constitutes four major components, which are as follows;
#
# * Inputs
# * Weights and Bias
# * Summation Functions
# * Activation or transformation functio

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The inputs (x) are fed into the input layer, which undergoes multiplication with the allotted weights (w) followed by experiencing addition in order to form weighted sums. Then these inputs weighted sums with their corresponding weights are executed on the pertinent activation function.

# %% [markdown]
# ## Weights and Bias
# when the input variable is fed into the network, a random value is given as a weight of that particular input, such that each individual weight represents the importance of that input in order to make correct predictions of the result

# %% [markdown]
# # Activation Functions
# a weighted sum of input is calculated based on weights and inputs provided. Then, the activation function comes into the picture that works on weighted sum and converts it into output.
# <br>
# ![image.png](https://editor.analyticsvidhya.com/uploads/42282Fig3.jpg)
# <br>
# Activation functions help model learn complex relationship that exists within the dataset. If we do not use the activation function in neurons and give weighted sum as output, in that case, computations will be difficult as there is no specific range for weighted sum. So, the activation function helps to keep output in a particular range.

# %% [markdown]
# ## Loss/ Cost Function

# %% [markdown]
# To train the model, we give input (departure location, arrival location and, departure date in case of train price prediction) to the network and let it predict the output making use of activation function. Then, we compare predicted output with the actual output and compute the error between two values. This error between two values is computed using loss/ cost function. The same process is repeated for entire training dataset and we get the average loss/error.
